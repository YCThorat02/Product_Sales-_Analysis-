# %% [markdown]
# <div style="background: linear-gradient(to right, blue, purple); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #FFffff;">
#     <strong>Loading and cheking the dataset</strong>
#   </p>
# </div>

# %%
import pandas as pd 
info= pd.read_csv(r"C:\Users\priyanka\Desktop\Brutal Baron 1 (CSV).csv",encoding='cp1252')
df=pd.DataFrame(info)
print(df.head(10))
df.isnull()
df.dropna()
df.fillna(0)
# Out:
#   Transaction ID              Product  Quantity  Unit Price (INR)        Date  \
# 0         TX0001           Smartwatch         9              8941  2024-04-12
# 1         TX0002           Desktop PC         9             19827  2024-02-06
# 2         TX0003           Desktop PC         4             16640  2023-12-16
# 3         TX0004             E-Reader         3              2945  2024-09-11
# 4         TX0005               Laptop         4              2848  2023-10-24
# 5         TX0006               Laptop         7             18703  2023-12-24
# 6         TX0007               Tablet         4              9640  2023-11-27
# 7         TX0008  External Hard Drive         7             15189  2024-07-13
# 8         TX0009               Tablet         6              4093  2024-01-30
# 9         TX0010           Smartphone         8              7088  2023-11-15
#
#    Customer Name              State Country Sales Channel Payment Type   Sales
# ...

# %%
print(df.head(2))
# Out:
#   Transaction ID     Product  Quantity  Unit Price (INR)        Date  \
# 0         TX0001  Smartwatch         9              8941  2024-04-12
# 1         TX0002  Desktop PC         9             19827  2024-02-06
#
#    Customer Name              State Country Sales Channel Payment Type   Sales
# 0  Vivaan Sastry  Arunachal Pradesh   India         Store  Credit Card   80469
# 1   Ishaan Madan             Odisha   India         Store  Credit Card  178443

# %% [markdown]
# <div style="background: linear-gradient(to right, blue, purple); padding: 10px; border-radius: 15px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #FFD700;">
#     <strong>Cheking Unique Product</strong>
#   </p>
# </div>

# %%
df['Product'].unique()
# Out:
# array(['Smartwatch', 'Desktop PC', 'E-Reader', 'Laptop', 'Tablet',
#        'External Hard Drive', 'Smartphone', 'Headphones', 'Printer',
#        'Camera'], dtype=object)

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Top 5 most sold Products by Quantity</strong>
#   </p>
# </div>

# %%
df.groupby('Product')['Quantity'].sum().sort_values(ascending=False).head()

import matplotlib.pyplot as plt 
most_product= df.groupby('Product')['Quantity'].sum().sort_values(ascending=False).head()
most_product.plot(kind='bar',color='skyblue')

plt.title("top 5 most sold product" , fontsize=20) #  top 5 most sold products by quantity
plt.xlabel("product")
plt.ylabel("Quantity")
for i, value in enumerate(most_product):
    plt.text(i, value + 1, str(value), ha='center', va='bottom',color="red")

plt.show()

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Total Sales value for each State</strong>
#   </p>
# </div>

# %%
df.groupby('State')['Sales'].sum().sort_values(ascending=False)
# Out:
# State
# Telangana            2485106
# Jharkhand            2369657
# Assam                2336202
# Chhattisgarh         2327912
# Manipur              2287237
# Tamil Nadu           2285125
# Kerala               2105939
# Uttarakhand          2103414
# Gujarat              2005827
# Arunachal Pradesh    2003161
# Punjab               1982025
# Odisha               1937488
# Nagaland             1933057
# Sikkim               1902753
# Himachal Pradesh     1822363
# West Bengal          1795464
# Meghalaya            1710873
# Tripura              1682846
# Karnataka            1674656
# Haryana              1621117
# Uttar Pradesh        1520672
# Andhra Pradesh       1519681
# Mizoram              1457875
# Rajasthan            1354795
# Maharashtra          1283803
# Goa                  1277871
# Bihar                1271799
# Madhya Pradesh       1143399
# Name: Sales, dtype: int64

# %%
import seaborn as sns
state=df.groupby('State')['Sales'].sum().sort_values(ascending=False)
colors = ['red' if i < 10 else 'blue' for i in range(len(state))]
ax = state.plot(kind="bar", color="blue", figsize=(18, 4))
plt.title("TOTAL SALES OF STATE",fontsize=20)
plt.xlabel("Stete Name")
plt.ylabel("sales in lac ")

#for i , value in enumerate(state):
   # plt.text(i,value+1,str(value), ha="center",va="bottom" , color="red")

plt.show()

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Avrage Unit price for each Product </strong>
#   </p>
# </div>

# %%
df.groupby('Product')['Unit Price (INR)'].mean()
# Out:
# Product
# Camera                  9565.181818
# Desktop PC             11242.194175
# E-Reader               11245.718750
# External Hard Drive    10182.240385
# Headphones             10849.657534
# Laptop                  9279.732673
# Printer                10367.725664
# Smartphone             11176.945055
# Smartwatch             10267.627273
# Tablet                 11248.515152
# Name: Unit Price (INR), dtype: float64

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Most Frequently used Payment Method</strong>
#   </p>
# </div>

# %%
df['Payment Type'].value_counts()
# Out:
# Payment Type
# Cash           225
# Net Banking    204
# UPI            199
# Credit Card    188
# Debit Card     184
# Name: count, dtype: int64

# %%
df['Total amount']= df['Quantity']  *  df['Unit Price (INR)']

# %%
df.columns
df.head()
# Out:
#   Transaction ID     Product  Quantity  Unit Price (INR)       Date  \
# 0         TX0001  Smartwatch         9              8941 2024-04-12
# 1         TX0002  Desktop PC         9             19827 2024-02-06
# 2         TX0003  Desktop PC         4             16640 2023-12-16
# 3         TX0004    E-Reader         3              2945 2024-09-11
# 4         TX0005      Laptop         4              2848 2023-10-24
#
#    Customer Name              State Country Sales Channel Payment Type  \
# 0  Vivaan Sastry  Arunachal Pradesh   India         Store  Credit Card
# 1   Ishaan Madan             Odisha   India         Store  Credit Card
# 2    Azad Sandhu              Bihar   India        Online  Credit Card
# 3   Shray Chawla            Manipur   India        Online  Credit Card
# 4      Zara Kata     Madhya Pradesh   India        Direct  Net Banking
#
#     Sales  Total amount
# 0   80469         80469
# 1  178443        178443
# 2   66560         66560
# 3    8835          8835
# ...

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Converting "Date" column to "Datetime" Format</strong>
#   </p>
# </div>

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
df.head(2)
# Out:
#   Transaction ID     Product  Quantity  Unit Price (INR)       Date  \
# 0         TX0001  Smartwatch         9              8941 2024-04-12
# 1         TX0002  Desktop PC         9             19827 2024-02-06
#
#    Customer Name              State Country Sales Channel Payment Type   Sales
# 0  Vivaan Sastry  Arunachal Pradesh   India         Store  Credit Card   80469
# 1   Ishaan Madan             Odisha   India         Store  Credit Card  178443

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Filtering rows where sales are greater than 50,000</strong>
#   </p>
# </div>

# %%
df[df['Sales']>50000]
# Out:
#     Transaction ID              Product  Quantity  Unit Price (INR)  \
# 0           TX0001           Smartwatch         9              8941
# 1           TX0002           Desktop PC         9             19827
# 2           TX0003           Desktop PC         4             16640
# 5           TX0006               Laptop         7             18703
# 7           TX0008  External Hard Drive         7             15189
# ..             ...                  ...       ...               ...
# 985         TX0986           Headphones         8             14859
# 993         TX0994               Tablet         6             13092
# 995         TX0996           Desktop PC         3             16668
# 996         TX0997              Printer         9              7752
# 997         TX0998               Camera         8              6466
#
#            Date  Customer Name              State Country Sales Channel  \
# 0    2024-04-12  Vivaan Sastry  Arunachal Pradesh   India         Store
# ...

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Transactions that occurred in 2024 only</strong>
#   </p>
# </div>

# %%
df[pd.to_datetime(df['Date']).dt.year == 2024] # Get transactions that occurred in 2024 only
# Out:
#     Transaction ID              Product  Quantity  Unit Price (INR)  \
# 0           TX0001           Smartwatch         9              8941
# 1           TX0002           Desktop PC         9             19827
# 3           TX0004             E-Reader         3              2945
# 7           TX0008  External Hard Drive         7             15189
# 8           TX0009               Tablet         6              4093
# ..             ...                  ...       ...               ...
# 991         TX0992               Tablet         3              9147
# 992         TX0993           Smartwatch         6              6483
# 995         TX0996           Desktop PC         3             16668
# 996         TX0997              Printer         9              7752
# 997         TX0998               Camera         8              6466
#
#            Date  Customer Name              State Country Sales Channel  \
# 0    2024-04-12  Vivaan Sastry  Arunachal Pradesh   India         Store
# ...

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>transactions per sales channel</strong>
#   </p>
# </div>

# %%
df['Sales Channel'].value_counts()
# Out:
# Sales Channel
# Store     346
# Online    336
# Direct    318
# Name: count, dtype: int64

# %%
df.groupby('Sales Channel')['Transaction ID'].count()
# Out:
# Sales Channel
# Direct    318
# Online    336
# Store     346
# Name: Transaction ID, dtype: int64

# %%
df.groupby('Product')[['Sales','Unit Price (INR)']].mean().reset_index()
# Out:
#                Product         Sales  Unit Price (INR)
# 0               Camera  46755.245455       9565.181818
# 1           Desktop PC  50653.582524      11242.194175
# 2             E-Reader  53533.354167      11245.718750
# 3  External Hard Drive  55371.057692      10182.240385
# 4           Headphones  54894.164384      10849.657534
# 5               Laptop  47347.366337       9279.732673
# 6              Printer  49079.858407      10367.725664
# 7           Smartphone  58740.901099      11176.945055
# 8           Smartwatch  47205.800000      10267.627273
# 9               Tablet  51217.040404      11248.515152

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>NO.OF Sales of Product</strong>
#   </p>
# </div>

# %%
df.groupby('Product')['Sales'].count().sort_values(ascending=True)
sales_product=df.groupby('Product')['Sales'].count()
sales_product.plot(kind="bar", color="green",figsize=(15,6),edgecolor="yellow")
plt.plot(sales_product.values, color='red', label='Trend Line', linewidth=3, marker='o',markerfacecolor='yellow',markeredgecolor='blue')
plt.title("NO.OF SALES OF PRODUCT",fontsize=20)
plt.xlabel("Product",color="red")
plt.ylabel("count of sales",color="red")
plt.xticks(color="blue")
plt.yticks(color="blue")
for i, value in enumerate(sales_product):
    plt.text(i, value + 1, str(value), ha='center', va='top',color="purple",
            
            bbox=dict(facecolor="yellow"
                     ))

plt.legend(loc='upper right')
plt.show()

# %%
df.groupby('Product')['Quantity'].sum().sort_values(ascending=False).head()
# Out:
# Product
# External Hard Drive    560
# Camera                 557
# Printer                540
# Laptop                 526
# Smartwatch             495
# Name: Quantity, dtype: int64

# %%
df.head(2)
# Out:
#   Transaction ID     Product  Quantity  Unit Price (INR)        Date  \
# 0         TX0001  Smartwatch         9              8941  2024-04-12
# 1         TX0002  Desktop PC         9             19827  2024-02-06
#
#    Customer Name              State Country Sales Channel Payment Type   Sales
# 0  Vivaan Sastry  Arunachal Pradesh   India         Store  Credit Card   80469
# 1   Ishaan Madan             Odisha   India         Store  Credit Card  178443

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Most Commonly Used Payment Type</strong>
#   </p>
# </div>

# %%
Payment_mode.plot(kind="bar" ,figsize=(8,6))
plt.title("Payment Method Usage",fontsize=20)
plt.xlabel("payment type")
plt.ylabel("count")
for i, value in enumerate(Payment_mode):
    plt.text(i,value+1,str(value),ha="center",va="bottom",color="red")
plt.show()

# %%
df.groupby('Payment Type')['Sales'].sum()
# Out:
# Payment Type
# Cash           10886530
# Credit Card    10460781
# Debit Card      9090654
# Net Banking    10111186
# UPI            10652966
# Name: Sales, dtype: int64

# %%
payment_sales=df.groupby('Payment Type')['Sales'].sum()

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Top Payment methods by Sales</strong>
#   </p>
# </div>

# %%
payment_sales.plot(kind="bar",color="green")
for i, value in enumerate(payment_sales):
    plt.text(i,value+1,str(value,) , ha="center" , va="bottom" ,color="red")

plt.title("Top Payment Methods by Sales",fontsize=20)
plt.xlabel("payment type")
plt.ylabel("sales in lac")
plt.show()

# %%
df.head(5)
# Out:
#   Transaction ID     Product  Quantity  Unit Price (INR)        Date  \
# 0         TX0001  Smartwatch         9              8941  2024-04-12
# 1         TX0002  Desktop PC         9             19827  2024-02-06
# 2         TX0003  Desktop PC         4             16640  2023-12-16
# 3         TX0004    E-Reader         3              2945  2024-09-11
# 4         TX0005      Laptop         4              2848  2023-10-24
#
#    Customer Name              State Country Sales Channel Payment Type   Sales
# 0  Vivaan Sastry  Arunachal Pradesh   India         Store  Credit Card   80469
# 1   Ishaan Madan             Odisha   India         Store  Credit Card  178443
# 2    Azad Sandhu              Bihar   India        Online  Credit Card   66560
# 3   Shray Chawla            Manipur   India        Online  Credit Card    8835
# 4      Zara Kata     Madhya Pradesh   India        Direct  Net Banking   11392

# %%
df.groupby('Sales Channel')['Sales'].sum()
# Out:
# Sales Channel
# Direct    15409758
# Online    17385072
# Store     18407287
# Name: Sales, dtype: int64

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Sales by Channel</strong>
#   </p>
# </div>

# %%
Channel=df.groupby('Sales Channel')['Sales'].sum()
Channel.plot(kind="bar",color="darkred",figsize=(10,5))
plt.title("Sales by Channel",fontsize=20)
plt.xlabel("Sales Channels",color="blue")
plt.ylabel("Sales",color="blue")
plt.xticks(color="red")
plt.yticks(color="red")
for i, value in  enumerate (Channel):
    plt.text(i,value+1,str(value),ha="center",va="bottom", color="blue")
plt.show()

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Contribution Of Channels in Sales</strong>
#   </p>
# </div>

# %%
expl=[0.01,0.01,0.01]
plt.pie(Channel,labels=Channel.index,explode=expl,autopct="%2.f%%")
plt.title("Contribution of Channels",fontsize=20)
plt.show()

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Sales by Product</strong>
#   </p>
# </div>
#  v>

# %%
df.groupby('Product')['Sales'].sum()
product=df.groupby('Product')['Sales'].sum()
product.plot(kind="bar",color="orange" ,figsize=(15,6),edgecolor="black")
for i, value in enumerate(product):
    plt.text(
        i, value + 1, str(value),ha="center", va="bottom",fontsize=10,color="white",
        bbox=dict(
            facecolor='green',      
            boxstyle='round,pad=0.1'  
        )
    )

# %%
df.head(2)
# Out:
#   Transaction ID     Product  Quantity  Unit Price (INR)        Date  \
# 0         TX0001  Smartwatch         9              8941  2024-04-12
# 1         TX0002  Desktop PC         9             19827  2024-02-06
#
#    Customer Name              State Country Sales Channel Payment Type   Sales
# 0  Vivaan Sastry  Arunachal Pradesh   India         Store  Credit Card   80469
# 1   Ishaan Madan             Odisha   India         Store  Credit Card  178443

# %%
df.groupby('Date')['Sales'].sum()
# Out:
# Date
# 2023-09-24    223746
# 2023-09-25    185518
# 2023-09-26     42057
# 2023-09-27    192414
# 2023-09-29    178906
#                ...
# 2024-09-19    125538
# 2024-09-20    146523
# 2024-09-21     17684
# 2024-09-22    132929
# 2024-09-23    263636
# Name: Sales, Length: 334, dtype: int64

# %% [markdown]
#  <div style="background-color:#00BFFF; padding: 10px; border-radius: 10px;">
#   <p style="font-size:27px; font-family: Arial, sans-serif; color: #000000
# ;">
#     <strong>Sales Performace over the Month and Year </strong>
#   </p>
# </div>
#  v>
# iv>
# iv>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df['Date'] = pd.to_datetime(df['Date'])
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.strftime('%b')  
df['Month_Num'] = df['Date'].dt.month       

monthly_sales = df.groupby(['Year', 'Month', 'Month_Num'])['Sales'].sum().reset_index()
monthly_sales = monthly_sales.sort_values(by='Month_Num')
heatmap_data = monthly_sales.pivot(index='Year', columns='Month', values='Sales')

plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".0f", cmap='Blues', linewidths=0.5)
plt.title("Month vs Year ")
plt.xlabel("Month")
plt.ylabel("Year")
plt.tight_layout()
plt.show()
